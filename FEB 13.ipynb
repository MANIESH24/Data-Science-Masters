# %% [raw]
# 1) When creating a custom exception in Python, it is recommended to inherit from the `Exception` class or one of its subclasses. Here's why it is important to use the `Exception` class as the base class for custom exceptions:
#
# 1. Consistency and Compatibility: Inheriting from the `Exception` class ensures that your custom exception behaves consistently with other built-in exceptions and follows the established exception hierarchy in Python. This allows your custom exception to be compatible with existing exception handling mechanisms and provides a familiar interface for developers.
#
# 2. Exception Handling: The `Exception` class provides a set of methods and attributes that are commonly used for exception handling, such as `__str__()` to provide a string representation of the exception, `__repr__()` to provide a detailed representation, and `args` to access the exception arguments. By inheriting from the `Exception` class, your custom exception inherits these functionalities, making it easier to handle and process the exception appropriately.
#
# 3. Catching and Filtering: When catching exceptions, you can use the base class `Exception` to catch all types of exceptions, including both built-in exceptions and your custom exception. This allows you to write more generic exception handlers that can handle a variety of exceptions without the need to explicitly list each exception type.
#
# 4. Code Organization and Clarity: Inheriting from the `Exception` class helps in organizing your code by clearly indicating that the class is intended to represent an exception. It improves code readability and makes it easier for other developers to understand the purpose and behavior of your custom exception.

# %%
##2)
def print_exception_hierarchy(exception_class, indent=0):
    print(" " * indent + exception_class.__name__)
    for subclass in exception_class.__subclasses__():
        print_exception_hierarchy(subclass, indent + 4)

# Print the exception hierarchy starting from the base Exception class
print_exception_hierarchy(Exception)
# Out:
# Exception
#     TypeError
#         FloatOperation
#         MultipartConversionError
#     StopAsyncIteration
#     StopIteration
#     ImportError
#         ModuleNotFoundError
#         ZipImportError
#     OSError
#         ConnectionError
#             BrokenPipeError
#             ConnectionAbortedError
#             ConnectionRefusedError
#             ConnectionResetError
#                 RemoteDisconnected
#         BlockingIOError
#         ChildProcessError
#         FileExistsError
#         FileNotFoundError
#         IsADirectoryError
#         NotADirectoryError
#         InterruptedError
#             InterruptedSystemCall
#         PermissionError
#         ProcessLookupError
#         TimeoutError
#         UnsupportedOperation
#         itimer_error
#         herror
#         gaierror
#         SSLError
#             SSLCertVerificationError
#             SSLZeroReturnError
#             SSLWantWriteError
#             SSLWantReadError
# ...

# %%
###3) 
dividend = 10
divisor = 0

try:
    result = dividend / divisor
    print(result)
except ZeroDivisionError:
    print("Error: Division by zero is not allowed.")
# Out:
# Error: Division by zero is not allowed.

# %%
###3) 
big_number = 10**1000

try:
    result = big_number * big_number
    print(result)
except OverflowError:
    print("Error: Result exceeds the maximum representable value.")
# Out:
# ...

# %% [raw]
# 4) The `LookupError` class in Python is a base class for exceptions that occur when a lookup or indexing operation fails. It encompasses errors such as `KeyError` and `IndexError`.
#
# 1. `KeyError`: This error occurs when you try to access a dictionary using a key that does not exist.
#
#    Example:
#    ```python
#    dictionary = {'a': 1, 'b': 2, 'c': 3}
#
#    try:
#        value = dictionary['d']
#        print(value)
#    except KeyError:
#        print("Error: Key does not exist in the dictionary.")
#    ```
#
#    In this example, we have a dictionary with keys 'a', 'b', and 'c'. We attempt to access the value associated with the key 'd'. Since the key 'd' does not exist in the dictionary, it raises a `KeyError`. The program catches the exception using a `try-except` block and prints an error message indicating that the key does not exist in the dictionary.
#
# 2. `IndexError`: This error occurs when you try to access a sequence (such as a list or a tuple) using an invalid index or slice.
#
#    Example:
#    ```python
#    my_list = [1, 2, 3]
#
#    try:
#        value = my_list[3]
#        print(value)
#    except IndexError:
#        print("Error: Index is out of range.")
#    ```
#
#    In this example, we have a list with three elements. We attempt to access the element at index 3, which is beyond the range of valid indices for this list. It raises an `IndexError`. The program catches the exception using a `try-except` block and prints an error message indicating that the index is out of range.
#
# The `LookupError` class provides a common base class for handling lookup-related errors like `KeyError` and `IndexError`. By catching `LookupError`, you can handle both types of errors in a similar manner, allowing you to write more generic exception handlers. It promotes code reuse and simplifies exception handling for cases where the exact type of lookup error is not important, but handling lookup-related exceptions is necessary.

# %% [raw]
# 5) `ImportError` is an exception in Python that is raised when an import statement fails to find and load a module or when there is an error in importing a module. It is a subclass of the built-in `Exception` class.
#
# The `ImportError` can occur due to various reasons, including:
#
# 1. The module or package you are trying to import does not exist.
# 2. The module or package is not installed in your Python environment.
# 3. There is an error in the module or package being imported (e.g., syntax error or missing dependencies).
#
# Example of `ImportError`:
# ```python
# try:
#     import non_existent_module
# except ImportError:
#     print("Error: Failed to import the module.")
# ```
#
# In this example, we attempt to import a module named `non_existent_module` that does not exist. As a result, it raises an `ImportError`. The program catches the exception using a `try-except` block and prints an error message indicating the failure to import the module.
#
# `ModuleNotFoundError` is a subclass of `ImportError` that specifically represents the error when a module or package is not found during import. It was introduced in Python 3.6 as a more specific exception for import-related errors.
#
# Example of `ModuleNotFoundError`:
# ```python
# try:
#     import non_existent_module
# except ModuleNotFoundError:
#     print("Error: The module could not be found.")
# ```
#
# In this example, we use the `ModuleNotFoundError` exception to catch the specific error when the module `non_existent_module` is not found. The program catches the exception and prints an error message indicating that the module could not be found.
#
# In summary, `ImportError` is a general exception that encompasses all import-related errors, while `ModuleNotFoundError` is a specific subclass of `ImportError` that represents the error when a module or package is not found during import.

# %% [raw]
# 6) Here are some best practices for exception handling in Python:
#
# 1. Be specific in exception handling: Catch specific exceptions whenever possible instead of using broad exception classes like `Exception` or `BaseException`. This allows you to handle different exceptions differently and provides more precise error handling.
#
# 2. Use multiple `except` blocks: If you expect different types of exceptions that require different handling, use multiple `except` blocks to handle each exception separately. This allows you to provide specific error handling for each type of exception.
#
# 3. Use the `finally` block: When necessary, use the `finally` block to specify code that should be executed regardless of whether an exception occurred or not. The `finally` block is useful for releasing resources or cleaning up operations that need to be performed regardless of the outcome of the exception handling.
#
# 4. Avoid using bare `except` statements: Avoid using bare `except` statements without specifying the exception type to catch. It can mask errors and make debugging difficult. Instead, catch specific exceptions or use `Exception` as a last resort if you have a good reason to catch all exceptions.
#
# 5. Handle exceptions at an appropriate level: Handle exceptions at a level of code where you have enough context and information to handle them effectively. Avoid catching exceptions too broadly at a high-level, as it may hide important error details and make troubleshooting more challenging.
#
# 6. Log exceptions: Use a logging framework to log exceptions and their relevant information. Logging helps in identifying and debugging issues and provides valuable information for troubleshooting.
#
# 7. Raise meaningful custom exceptions: When appropriate, create custom exceptions that provide meaningful information about the error or exceptional situation. Custom exceptions can make your code more readable and help in handling specific cases more effectively.
#
# 8. Keep exception handling concise: Avoid writing excessive or overly complex exception handling code. Keep the exception handling logic concise and focused on the specific error handling requirements. Clear and concise code is easier to understand and maintain.
#
# 9. Document exception behavior: Document the exceptions that can be raised by your code and their expected behavior. Provide clear documentation on how exceptions should be handled, what they signify, and any actions or precautions that need to be taken when specific exceptions occur.
#
# 10. Test exception handling: Write unit tests to validate the behavior of your exception handling code. Test both the cases where exceptions are expected to be raised and the cases where exceptions should not occur. This ensures that your exception handling is working correctly and provides confidence in the stability and reliability of your code.
#
# By following these best practices, you can write more robust and maintainable code with effective exception handling in Python.
